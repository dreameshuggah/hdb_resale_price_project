# %%
import xgboost as xgb

print("Loading old binary model...")
model = xgb.XGBRegressor()
model.load_model('model.xgb')

print("Saving as modern JSON format...")
model.save_model('model.json')
print("Conversion complete! You can now use model.json")
# Out:
# Loading old binary model...
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Input In [1], in <module>
#       3 print("Loading old binary model...")
#       4 model = xgb.XGBRegressor()
# ----> 5 model.load_model('model.xgb')
#       7 print("Saving as modern JSON format...")
#       8 model.save_model('model.json')
#
# File /usr/local/lib/python3.9/site-packages/xgboost/sklearn.py:599, in XGBModel.load_model(self, fname)
#     597 if not hasattr(self, '_Booster'):
#     598     self._Booster = Booster({'n_jobs': self.n_jobs})
# --> 599 self.get_booster().load_model(fname)
#     600 meta_str = self.get_booster().attr('scikit_learn')
#     601 if meta_str is None:
#     602     # FIXME(jiaming): This doesn't have to be a problem as most of the needed
#     603     # information like num_class and objective is in Learner class.
#
# ...
